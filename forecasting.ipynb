# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install pandas requests beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cot_reports as cot

# Example: cot_hist()
df = cot.cot_hist(cot_report_type= 'traders_in_financial_futures_futopt')
# Out:
# Selected: COT Traders in Financial Futures report. Futures and Options.
# Stored the extracted file C_TFF_2006_2016.txt in the working directory.

# %%
df['Market_and_Exchange_Names'].value_counts()
# Out:
# Market_and_Exchange_Names
# CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE                    551
# DOW JONES INDUSTRIAL AVG- x $5 - CHICAGO BOARD OF TRADE          551
# U.S. DOLLAR INDEX - ICE FUTURES U.S.                             551
# 3-MONTH EURODOLLARS - CHICAGO MERCANTILE EXCHANGE                551
# 30-DAY FEDERAL FUNDS - CHICAGO BOARD OF TRADE                    551
# 5-YEAR U.S. TREASURY NOTES - CHICAGO BOARD OF TRADE              551
# 10-YEAR U.S. TREASURY NOTES - CHICAGO BOARD OF TRADE             551
# 2-YEAR U.S. TREASURY NOTES - CHICAGO BOARD OF TRADE              551
# U.S. TREASURY BONDS - CHICAGO BOARD OF TRADE                     551
# E-MINI S&P 400 STOCK INDEX - CHICAGO MERCANTILE EXCHANGE         551
# SWISS FRANC - CHICAGO MERCANTILE EXCHANGE                        551
# NIKKEI STOCK AVERAGE - CHICAGO MERCANTILE EXCHANGE               551
# NASDAQ-100 STOCK INDEX (MINI) - CHICAGO MERCANTILE EXCHANGE      551
# ...

# %%
df = cot.cot_year(year = 2024, cot_report_type = 'traders_in_financial_futures_fut')
# Out:
# Selected: traders_in_financial_futures_fut
# Downloaded single year data from: 2024
# Stored the file FinFutYY.txt in the working directory.

# %%
df['Contract_Units'].unique()
# Out:
# array(['(CONTRACTS OF CAD 100,000)', '(CONTRACTS OF CHF 125,000)',
#        '(CONTRACTS OF GBP 62,500)', '(CONTRACTS OF JPY 12,500,000)',
#        '(CONTRACTS OF EUR 125,000)', '(CONTRACTS OF AUD 100,000)',
#        '(CONTRACTS OF 100,000 USD)', '(CONTRACTS OF MXN 500,000)',
#        '(CONTRACTS OF BRL 100,000)', '(CONTRACTS OF NZD 100,000)',
#        '(CONTRACTS OF ZAR 500,000)', '($5 X DJIA INDEX)',
#        '($100 X DJ US REAL ESTATE INDEX)', '($0.5 X DJIA INDEX)',
#        '(S&P 500 INDEX X $50.00)',
#        '($100 x S&P Select Sector Consumer Staples Index price)',
#        '($100 x S&P Select Sector Energy Index price)',
#        '($50 X S&P 500 INDEX)',
#        '($250 x S&P Select Sector Financial Index price)',
#        '($100 x S&P Select Sector Health Care Index price)',
#        '($100 x S&P Select Sector Industrial Index price)',
#        '($100 x S&P Select Sector Materials Index price)',
#        '($100 x S&P Select Sector Technology Index price)',
# ...

# %%
df['Market_and_Exchange_Names'].unique()
# Out:
# array(['CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE',
#        'SWISS FRANC - CHICAGO MERCANTILE EXCHANGE',
#        'BRITISH POUND - CHICAGO MERCANTILE EXCHANGE',
#        'JAPANESE YEN - CHICAGO MERCANTILE EXCHANGE',
#        'EURO FX - CHICAGO MERCANTILE EXCHANGE',
#        'AUSTRALIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE',
#        'EURO FX/BRITISH POUND XRATE - CHICAGO MERCANTILE EXCHANGE',
#        'EURO FX/JAPANESE YEN XRATE - CHICAGO MERCANTILE EXCHANGE',
#        'USD/CHINESE RENMINBI-OFFSHORE  - CHICAGO MERCANTILE EXCHANGE',
#        'MEXICAN PESO - CHICAGO MERCANTILE EXCHANGE',
#        'BRAZILIAN REAL - CHICAGO MERCANTILE EXCHANGE',
#        'NZ DOLLAR - CHICAGO MERCANTILE EXCHANGE',
#        'SO AFRICAN RAND - CHICAGO MERCANTILE EXCHANGE',
#        'DJIA Consolidated - CHICAGO BOARD OF TRADE',
#        'DJIA x $5 - CHICAGO BOARD OF TRADE',
#        'DOW JONES U.S. REAL ESTATE IDX - CHICAGO BOARD OF TRADE',
#        'MICRO E-MINI DJIA (x$0.5) - CHICAGO BOARD OF TRADE',
# ...

# %%
df['CFTC_Market_Code'].unique()
# Out:
# array(['CME ', 'CBT ', 'ICUS', 'FREX', 'E   '], dtype=object)

# %%
df['Contract_Units'].unique()
# Out:
# array(['(CONTRACTS OF CAD 100,000)', '(CONTRACTS OF CHF 125,000)',
#        '(CONTRACTS OF GBP 62,500)', '(CONTRACTS OF JPY 12,500,000)',
#        '(CONTRACTS OF EUR 125,000)', '(CONTRACTS OF AUD 100,000)',
#        '(CONTRACTS OF 100,000 USD)', '(CONTRACTS OF MXN 500,000)',
#        '(CONTRACTS OF BRL 100,000)', '(CONTRACTS OF NZD 100,000)',
#        '(CONTRACTS OF ZAR 500,000)', '($5 X DJIA INDEX)',
#        '($100 X DJ US REAL ESTATE INDEX)', '($0.5 X DJIA INDEX)',
#        '(S&P 500 INDEX X $50.00)',
#        '($100 x S&P Select Sector Consumer Staples Index price)',
#        '($100 x S&P Select Sector Energy Index price)',
#        '($50 X S&P 500 INDEX)',
#        '($250 x S&P Select Sector Financial Index price)',
#        '($100 x S&P Select Sector Health Care Index price)',
#        '($100 x S&P Select Sector Industrial Index price)',
#        '($100 x S&P Select Sector Materials Index price)',
#        '($100 x S&P Select Sector Technology Index price)',
# ...

# %%
df.columns
# Out:
# Index(['Market_and_Exchange_Names', 'As_of_Date_In_Form_YYMMDD',
#        'Report_Date_as_YYYY-MM-DD', 'CFTC_Contract_Market_Code',
#        'CFTC_Market_Code', 'CFTC_Region_Code', 'CFTC_Commodity_Code',
#        'Open_Interest_All', 'Dealer_Positions_Long_All',
#        'Dealer_Positions_Short_All', 'Dealer_Positions_Spread_All',
#        'Asset_Mgr_Positions_Long_All', 'Asset_Mgr_Positions_Short_All',
#        'Asset_Mgr_Positions_Spread_All', 'Lev_Money_Positions_Long_All',
#        'Lev_Money_Positions_Short_All', 'Lev_Money_Positions_Spread_All',
#        'Other_Rept_Positions_Long_All', 'Other_Rept_Positions_Short_All',
#        'Other_Rept_Positions_Spread_All', 'Tot_Rept_Positions_Long_All',
#        'Tot_Rept_Positions_Short_All', 'NonRept_Positions_Long_All',
#        'NonRept_Positions_Short_All', 'Change_in_Open_Interest_All',
#        'Change_in_Dealer_Long_All', 'Change_in_Dealer_Short_All',
#        'Change_in_Dealer_Spread_All', 'Change_in_Asset_Mgr_Long_All',
# ...

# %%
df = cotd.cot_year(year = 2024, cot_report_type = 'traders_in_financial_futures_fut')
# Out:
# Selected: traders_in_financial_futures_fut
# Downloaded single year data from: 2024
# Stored the file FinFutYY.txt in the working directory.

# %%
df
# Out:
#               Market_and_Exchange_Names  As_of_Date_In_Form_YYMMDD  \
# 0    WHEAT-SRW - CHICAGO BOARD OF TRADE                     240723
# 1    WHEAT-SRW - CHICAGO BOARD OF TRADE                     240716
# 2    WHEAT-SRW - CHICAGO BOARD OF TRADE                     240709
# 3    WHEAT-SRW - CHICAGO BOARD OF TRADE                     240702
# 4    WHEAT-SRW - CHICAGO BOARD OF TRADE                     240625
# ..                                  ...                        ...
# 385         COFFEE C - ICE FUTURES U.S.                     240130
# 386         COFFEE C - ICE FUTURES U.S.                     240123
# 387         COFFEE C - ICE FUTURES U.S.                     240116
# 388         COFFEE C - ICE FUTURES U.S.                     240109
# 389         COFFEE C - ICE FUTURES U.S.                     240102
#
#     As_of_Date_In_Form_YYYY-MM-DD  CFTC_Contract_Market_Code CFTC_Market_Code  \
# 0                      2024-07-23                       1602             CBT
# ...

# %%
df['CFTC_Market_Code'].value_counts()
# Out:
# CFTC_Market_Code
# CME     1159
# CBT      427
# ICUS      90
# FREX      60
# E         30
# Name: count, dtype: int64

# %%
import cot_reports as cot

# Example: cot_hist()
df = cot.cot_hist(cot_report_type= 'traders_in_financial_futures_futopt')
# cot_hist() downloads the historical bulk file for the specified report type, in this example the Traders in Financial Futures Futures-and-Options Combined report. Returns the data as dataframe.

# Example: cot_year()
df = cot.cot_year(year = 2024, cot_report_type = 'traders_in_financial_futures_fut')
# cot_year() downloads the single year file of the specified report type and year. Returns the data as dataframe.

# Example for collecting data of a few years, here from 2017 to 2020, of a specified report:
df = pd.DataFrame()
begin_year = 2017
end_year = 2020
for i in range(begin_year, end_year + 1):
    single_year = pd.DataFrame(cot.cot_year(i, cot_report_type='legacy_futopt')) 
    df = df.append(single_year, ignore_index=True)

# Example: cot_all()
df = cot.cot_all(cot_report_type='legacy_fut')
# cot_all() downloads the historical bulk file and all remaining single year files of the specified report type.  Returns the data as dataframe.

# %%
df = pd.read_csv('ml_set_1day.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df = df.set_index('Date')

# %%
# Plotting the data
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'], marker='o', linestyle='-', markersize=1, label='Close')
plt.plot(df.index, df['l1_open'], marker='s', linestyle='-', markersize=1, label='l1_open')
plt.plot(df.index, df['l1_high'], marker='^', linestyle='-', markersize=1, label='l1_high')

# Adding titles and labels
plt.title('Stock Prices')
plt.xlabel('Index')
plt.ylabel('Price')

# Adding legend
plt.legend()

# Rotate x-tick labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.show()

# %%
forecast = pd.read_excel('Azure output example.xlsx', skiprows=4)
# forecast['date'] = pd.to_datetime(forecast['date'], format='%d/%m/%Y')

# %%
forecast.columns = ['Date', 'Actual', 'forecast', 'Lower', 'Upper']

# %%
forecast = forecast[1:]

# %%
forecast['Date'] = pd.to_datetime(forecast['Date'], format='%d/%m/%Y')

# %%
forecast['Actual'] = forecast['Actual'].str.split(' ').str[-1]
forecast['forecast'] = forecast['forecast'].str.split(' ').str[-1]
forecast['Lower'] = forecast['Lower'].str.split(' ').str[-1]
forecast['Upper'] = forecast['Upper'].str.split(' ').str[-1]

# %%
# forecast = forecast.set_index('Date')
forecast[['Actual', 'forecast', 'Lower', 'Upper']] = forecast[['Actual', 'forecast', 'Lower', 'Upper']].astype(float)

# %%
forecast[['Actual', 'forecast']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df = df[1:]

# %%
# Plotting the data
plt.figure(figsize=(10, 6))

# Plot columns from the first dataframe
plt.plot(df.index, df['Close'], label='Close')

# Plot columns from the second dataframe
plt.plot(forecast.index, forecast['Actual'], label='Actual')
plt.plot(forecast.index, forecast['forecast'], label='Forecast')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Close Price, Actual, and Forecast')
plt.legend()
plt.grid(True)
plt.show()

# %%
from prophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = df.reset_index()

# %%
df.columns = ['ds', 'y']

# %%
m = Prophet(daily_seasonality=True)
m.fit(df)
# Out:
# 00:17:11 - cmdstanpy - INFO - Chain [1] start processing
# 00:17:11 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Python
future = m.make_future_dataframe(periods=25)
future.tail()
# Out:
#            ds
# 44 2024-06-06
# 45 2024-06-07
# 46 2024-06-08
# 47 2024-06-09
# 48 2024-06-10

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#            ds       yhat  yhat_lower  yhat_upper
# 44 2024-06-06  68.392060   61.957312   74.384591
# 45 2024-06-07  66.760067   59.812791   72.740166
# 46 2024-06-08  55.251071   47.728783   61.797728
# 47 2024-06-09  55.090771   47.141576   61.949429
# 48 2024-06-10  65.202634   56.903423   72.737713

# %%
df = df.set_index('ds')

# %%
forecast = forecast[~(forecast['yhat'] <= 0)]

# %%
# Plotting the data
plt.figure(figsize=(10, 6))

# Plot columns from the first dataframe
plt.plot(df.index, df['y'], label='Close')

# Plot columns from the second dataframe
plt.plot(forecast['ds'], forecast['yhat'], label='Pred')
# plt.plot(forecast.index, forecast['forecast'], label='Forecast')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Close Price, Actual, and Forecast')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd

# Assuming df1 and df2 are your dataframes

# Set the Date column as the index for both dataframes
# df.set_index('Date', inplace=True)
# forecast.set_index('Date', inplace=True)

# Plot the Close price and Actual columns from df1, and the Forecast column from df2
df['Close'].plot()
forecast[['Actual','forecast']].fillna(0).plot()

# Show the plot
plt.show()

# %%
df.reset_index()[['Date', 'Close']].head(20)
# Out:
#          Date  Close
# 0  2010-09-24  15.30
# 1  2010-09-27  15.39
# 2  2010-09-28  15.67
# 3  2010-09-29  15.64
# 4  2010-09-30  15.35
# 5  2010-10-01  15.38
# 6  2010-10-04  15.27
# 7  2010-10-05  15.55
# 8  2010-10-06  15.57
# 9  2010-10-07  15.50
# 10 2010-10-08  15.57
# 11 2010-10-11  15.84
# 12 2010-10-12  15.75
# 13 2010-10-13  15.63
# 14 2010-10-14  15.54
# 15 2010-10-15  15.45
# 16 2010-10-18  15.38
# 17 2010-10-19  15.05
# 18 2010-10-20  15.16
# 19 2010-10-21  14.85

# %%
forecast.columns
# Out:
# Index(['date', 'Actual ', 'Forecast ', 'lower interval_50% ',
#        'higher interval_50%'],
#       dtype='object')

# %%
forecast.columns = ['date', 'Actual ', 'Forecast ', 'lower interval_50% ',
       'higher interval_50%']

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 forecast[['Forecast']]
#
# File /opt/anaconda3/envs/junction/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/junction/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...
